# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\dell\Desktop\kidney_disease.csv')

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#        ...        pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0      ...         44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1      ...         38  6000  NaN   no   no   no  good   no   no            ckd
# 2      ...         31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3      ...         32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4      ...         35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data=data.drop(['id'],axis=1)
data
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.020  1.0  0.0       NaN    normal  notpresent  notpresent
# 1     7.0   50.0  1.020  4.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.010  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.010  2.0  0.0    normal    normal  notpresent  notpresent
# 5    60.0   90.0  1.015  3.0  0.0       NaN       NaN  notpresent  notpresent
# 6    68.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent  notpresent
# 7    24.0    NaN  1.015  2.0  4.0    normal  abnormal  notpresent  notpresent
# 8    52.0  100.0  1.015  3.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 10   50.0   60.0  1.010  2.0  4.0       NaN  abnormal     present  notpresent
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EB06B32518>,
# ...
#       dtype=object)

# %%
sns.set()
data ['age'].plot (kind = 'hist', bins=10)

# %%
import seaborn as sns
sns.set()
data ['bp'].plot (kind = 'hist', bins=10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
# age               391 non-null float64
# bp                388 non-null float64
# sg                353 non-null float64
# al                354 non-null float64
# su                351 non-null float64
# rbc               248 non-null object
# pc                335 non-null object
# pcc               396 non-null object
# ba                396 non-null object
# bgr               356 non-null float64
# bu                381 non-null float64
# sc                383 non-null float64
# sod               313 non-null float64
# pot               312 non-null float64
# hemo              348 non-null float64
# pcv               330 non-null object
# wc                295 non-null object
# rc                270 non-null object
# htn               398 non-null object
# dm                398 non-null object
# cad               398 non-null object
# ...

# %%
#to find the correlation
from matplotlib import rcParams
from matplotlib.cm import rainbow
rcParams['figure.figsize'] = 20, 14
plt.matshow(data.corr())
plt.yticks(np.arange(data.shape[1]), data.columns)
plt.xticks(np.arange(data.shape[1]), data.columns)
plt.colorbar()

# %%
data=data.dropna()
data
# Out:
#       age     bp     sg   al   su       rbc        pc         pcc          ba  \
# 3    48.0   70.0  1.005  4.0  0.0    normal  abnormal     present  notpresent
# 9    53.0   90.0  1.020  2.0  0.0  abnormal  abnormal     present  notpresent
# 11   63.0   70.0  1.010  3.0  0.0  abnormal  abnormal     present  notpresent
# 14   68.0   80.0  1.010  3.0  2.0    normal  abnormal     present     present
# 20   61.0   80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 22   48.0   80.0  1.025  4.0  0.0    normal  abnormal  notpresent  notpresent
# 27   69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent  notpresent
# 48   73.0   70.0  1.005  0.0  0.0    normal    normal  notpresent  notpresent
# 58   73.0   80.0  1.020  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# 71   46.0   60.0  1.010  1.0  0.0    normal    normal  notpresent  notpresent
# 74   56.0   90.0  1.015  2.0  0.0  abnormal  abnormal  notpresent  notpresent
# ...

# %%
dataset = data.select_dtypes(include=['object'])
dataset
# Out:
#           rbc        pc         pcc          ba pcv      wc   rc  htn   dm  \
# 3      normal  abnormal     present  notpresent  32    6700  3.9  yes   no
# 9    abnormal  abnormal     present  notpresent  29   12100  3.7  yes  yes
# 11   abnormal  abnormal     present  notpresent  32    4500  3.8  yes  yes
# 14     normal  abnormal     present     present  16   11000  2.6  yes  yes
# 20   abnormal  abnormal  notpresent  notpresent  24    9200  3.2  yes  yes
# 22     normal  abnormal  notpresent  notpresent  32    6900  3.4  yes   no
# 27     normal  abnormal  notpresent  notpresent  37    9600  4.1  yes  yes
# 48     normal    normal  notpresent  notpresent  29   18900  3.5  yes  yes
# 58   abnormal  abnormal  notpresent  notpresent  33    7200  4.3  yes  yes
# 71     normal    normal  notpresent  notpresent  28   14600  3.2  yes  yes
# 74   abnormal  abnormal  notpresent  notpresent  29    6400  3.4  yes   no
# ...

# %%
data = pd.get_dummies(data, columns = ['rbc','pc', 'pcc', 'ba','htn', 'dm', 'cad','appet', 'pe', 'ane']) 
#to convert categorical values to numerical values (excluding Nan as they have been already dropped)

# %%
#encoding the target classification we dont need separate columns for its categorical vales but just encoded in the same column
#That's why label encoding is used
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()

data['classification']= labelencoder_X.fit_transform(data['classification'])

# %%
data
# Out:
#       age     bp     sg   al   su    bgr     bu    sc    sod   pot  ...    \
# 3    48.0   70.0  1.005  4.0  0.0  117.0   56.0   3.8  111.0   2.5  ...
# 9    53.0   90.0  1.020  2.0  0.0   70.0  107.0   7.2  114.0   3.7  ...
# 11   63.0   70.0  1.010  3.0  0.0  380.0   60.0   2.7  131.0   4.2  ...
# 14   68.0   80.0  1.010  3.0  2.0  157.0   90.0   4.1  130.0   6.4  ...
# 20   61.0   80.0  1.015  2.0  0.0  173.0  148.0   3.9  135.0   5.2  ...
# 22   48.0   80.0  1.025  4.0  0.0   95.0  163.0   7.7  136.0   3.8  ...
# 27   69.0   70.0  1.010  3.0  4.0  264.0   87.0   2.7  130.0   4.0  ...
# 48   73.0   70.0  1.005  0.0  0.0   70.0   32.0   0.9  125.0   4.0  ...
# 58   73.0   80.0  1.020  2.0  0.0  253.0  142.0   4.6  138.0   5.8  ...
# 71   46.0   60.0  1.010  1.0  0.0  163.0   92.0   3.3  141.0   4.0  ...
# 74   56.0   90.0  1.015  2.0  0.0  129.0  107.0   6.7  131.0   4.8  ...
# 76   48.0   80.0  1.005  4.0  0.0  133.0  139.0   8.5  132.0   5.5  ...
# ...

# %%
dataset = data.select_dtypes(include=['object'])
dataset
# Out:
#     pcv      wc   rc
# 3    32    6700  3.9
# 9    29   12100  3.7
# 11   32    4500  3.8
# 14   16   11000  2.6
# 20   24    9200  3.2
# 22   32    6900  3.4
# 27   37    9600  4.1
# 48   29   18900  3.5
# 58   33    7200  4.3
# 71   28   14600  3.2
# 74   29    6400  3.4
# 76   36  \t6200    4
# 84   22    3800  2.1
# 90   40    9800  4.2
# 91   52   12500  5.6
# 92   33    5600  3.6
# 93   30    7000  3.2
# 127  35   15200  4.3
# 128  23    5000  2.9
# 130  22   16300  2.7
# 133  37  \t8400    8
# 144  33   10500  4.1
# 147  25   15200    3
# 153  22   14600  2.9
# 157  39    7900  3.9
# 159  35   10900  4.3
# 171  26   12800  3.1
# 176  23   12400  3.9
# 181  30   19100  3.7
# 189  29    7500  3.4
# ..   ..     ...  ...
# 368  45    9400  5.9
# 369  46   10300  4.8
# 370  50    9300  5.4
# 371  51    6500    5
# 372  52   10500  5.5
# 373  47    9200  4.9
# 374  40    8000  6.4
# 375  48    9700  5.6
# 376  53    9100  5.2
# 377  49    6400  4.8
# 379  50    5400  5.7
# ...

# %%
#still we are left with three columns that are pcv, wc, rc but they contain int and null values
#Therefore, typecasting is done
data = data.convert_objects(convert_numeric=True)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
data.select_dtypes(include=['object'])
# Out:
# Empty DataFrame
# Columns: []
# Index: [3, 9, 11, 14, 20, 22, 27, 48, 58, 71, 74, 76, 84, 90, 91, 92, 93, 127, 128, 130, 133, 144, 147, 153, 157, 159, 171, 176, 181, 189, 190, 196, 198, 210, 212, 213, 225, 226, 229, 242, 246, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 269, 270, 271, 272, 275, 277, 278, 279, 281, 282, 284, 285, 286, 289, 291, 292, 296, 298, 299, 301, 304, 305, 306, 307, 308, 310, 311, 313, 314, 317, 318, 320, 321, 323, 325, 326, 327, 329, 331, ...]
#
# [158 rows x 0 columns]

# %%
y = data['classification']
X = data.drop(['classification'], axis = 1)

# %%
y
# Out:
# 3      0
# 9      0
# 11     0
# 14     0
# 20     0
# 22     0
# 27     0
# 48     0
# 58     0
# 71     0
# 74     0
# 76     0
# 84     0
# 90     0
# 91     0
# 92     0
# 93     0
# 127    0
# 128    0
# 130    0
# 133    0
# 144    0
# 147    0
# 153    0
# 157    0
# 159    0
# 171    0
# 176    0
# 181    0
# 189    0
#       ..
# 368    1
# 369    1
# 370    1
# 371    1
# 372    1
# 373    1
# 374    1
# 375    1
# 376    1
# 377    1
# 379    1
# 380    1
# 382    1
# 383    1
# 384    1
# 385    1
# 386    1
# 387    1
# 388    1
# 389    1
# 390    1
# 391    1
# 392    1
# 393    1
# 394    1
# 395    1
# 396    1
# 397    1
# 398    1
# 399    1
# Name: classification, Length: 158, dtype: int64

# %%
X
# Out:
#       age     bp     sg   al   su    bgr     bu    sc    sod   pot  ...    \
# 3    48.0   70.0  1.005  4.0  0.0  117.0   56.0   3.8  111.0   2.5  ...
# 9    53.0   90.0  1.020  2.0  0.0   70.0  107.0   7.2  114.0   3.7  ...
# 11   63.0   70.0  1.010  3.0  0.0  380.0   60.0   2.7  131.0   4.2  ...
# 14   68.0   80.0  1.010  3.0  2.0  157.0   90.0   4.1  130.0   6.4  ...
# 20   61.0   80.0  1.015  2.0  0.0  173.0  148.0   3.9  135.0   5.2  ...
# 22   48.0   80.0  1.025  4.0  0.0   95.0  163.0   7.7  136.0   3.8  ...
# 27   69.0   70.0  1.010  3.0  4.0  264.0   87.0   2.7  130.0   4.0  ...
# 48   73.0   70.0  1.005  0.0  0.0   70.0   32.0   0.9  125.0   4.0  ...
# 58   73.0   80.0  1.020  2.0  0.0  253.0  142.0   4.6  138.0   5.8  ...
# 71   46.0   60.0  1.010  1.0  0.0  163.0   92.0   3.3  141.0   4.0  ...
# 74   56.0   90.0  1.015  2.0  0.0  129.0  107.0   6.7  131.0   4.8  ...
# 76   48.0   80.0  1.005  4.0  0.0  133.0  139.0   8.5  132.0   5.5  ...
# ...

# %%
X.shape
# Out:
# (158, 34)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
X_train
# Out:
#       age     bp     sg   al   su    bgr     bu    sc    sod   pot  ...    \
# 360  35.0   60.0  1.025  0.0  0.0  105.0   39.0   0.5  135.0   3.9  ...
# 344  64.0   60.0  1.020  0.0  0.0  106.0   27.0   0.7  150.0   3.3  ...
# 321  65.0   60.0  1.020  0.0  0.0  109.0   39.0   1.0  144.0   3.5  ...
# 275  52.0   80.0  1.020  0.0  0.0  125.0   22.0   1.2  139.0   4.6  ...
# 392  57.0   80.0  1.020  0.0  0.0  133.0   48.0   1.2  147.0   4.3  ...
# 128  52.0   90.0  1.015  4.0  3.0  224.0  166.0   5.6  133.0  47.0  ...
# 84   59.0   70.0  1.010  3.0  0.0   76.0  186.0  15.0  135.0   7.6  ...
# 71   46.0   60.0  1.010  1.0  0.0  163.0   92.0   3.3  141.0   4.0  ...
# 196  49.0  100.0  1.010  3.0  0.0  129.0  158.0  11.8  122.0   3.2  ...
# 304  33.0   80.0  1.025  0.0  0.0  128.0   38.0   0.6  135.0   3.9  ...
# 258  42.0   80.0  1.020  0.0  0.0   98.0   20.0   0.5  140.0   3.5  ...
# 380  59.0   60.0  1.020  0.0  0.0  113.0   23.0   1.1  139.0   3.5  ...
# ...

# %%
X_test
# Out:
#       age    bp     sg   al   su    bgr     bu   sc    sod  pot  ...    dm_0  \
# 368  30.0  80.0  1.025  0.0  0.0   82.0   42.0  0.7  146.0  5.0  ...       1
# 252  45.0  80.0  1.025  0.0  0.0   82.0   49.0  0.6  147.0  4.4  ...       1
# 374  79.0  80.0  1.025  0.0  0.0  111.0   44.0  1.2  146.0  3.6  ...       1
# 398  17.0  60.0  1.025  0.0  0.0  114.0   50.0  1.0  135.0  4.9  ...       1
# 317  58.0  70.0  1.020  0.0  0.0  102.0   48.0  1.2  139.0  4.3  ...       1
# 189  64.0  60.0  1.010  4.0  1.0  239.0   58.0  4.3  137.0  5.4  ...       0
# 326  47.0  60.0  1.020  0.0  0.0  109.0   25.0  1.1  141.0  4.7  ...       1
# 329  33.0  60.0  1.025  0.0  0.0   80.0   25.0  0.9  146.0  3.5  ...       1
# 325  58.0  80.0  1.020  0.0  0.0  100.0   50.0  1.2  140.0  3.5  ...       1
# 382  48.0  80.0  1.025  0.0  0.0   75.0   22.0  0.8  137.0  5.0  ...       1
# 130  50.0  90.0  1.010  2.0  0.0  128.0  208.0  9.2  134.0  4.8  ...       1
# ...

# %%
y_train
# Out:
# 360    1
# 344    1
# 321    1
# 275    1
# 392    1
# 128    0
# 84     0
# 71     0
# 196    0
# 304    1
# 258    1
# 380    1
# 364    1
# 388    1
# 387    1
# 291    1
# 377    1
# 262    1
# 366    1
# 307    1
# 396    1
# 249    0
# 278    1
# 355    1
# 171    0
# 376    1
# 298    1
# 391    1
# 225    0
# 292    1
#       ..
# 271    1
# 261    1
# 342    1
# 257    1
# 397    1
# 265    1
# 255    1
# 313    1
# 144    0
# 264    1
# 394    1
# 369    1
# 226    0
# 390    1
# 9      0
# 259    1
# 370    1
# 338    1
# 331    1
# 354    1
# 311    1
# 289    1
# 359    1
# 399    1
# 133    0
# 284    1
# 341    1
# 91     0
# 320    1
# 337    1
# Name: classification, Length: 142, dtype: int64

# %%
y_test
# Out:
# 368    1
# 252    1
# 374    1
# 398    1
# 317    1
# 189    0
# 326    1
# 329    1
# 325    1
# 382    1
# 130    0
# 263    1
# 92     0
# 281    1
# 157    0
# 190    0
# Name: classification, dtype: int64

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
dt_scores = []
for i in range(1, len(X.columns) + 1):
    dt_classifier = DecisionTreeClassifier(max_features = i, random_state = 0)
    dt_classifier.fit(X_train, y_train)
    dt_scores.append(dt_classifier.score(X_test, y_test))

# %%
plt.plot([i for i in range(1, len(X.columns) + 1)], dt_scores, color = 'green')
for i in range(1, len(X.columns) + 1):
    plt.text(i, dt_scores[i-1], (i, dt_scores[i-1]))
plt.xticks([i for i in range(1, len(X.columns) + 1)])
plt.xlabel('Max features')
plt.ylabel('Scores')
plt.title('Decision Tree Classifier scores for different number of maximum features')
# Out:
# Text(0.5,1,'Decision Tree Classifier scores for different number of maximum features')

# %%
from sklearn.metrics import accuracy_score
print("The score for Decision Tree Classifier is ",dt_scores[17]*100,"%")
# Out:
# The score for Decision Tree Classifier is  100.0 %

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 12, criterion='entropy', random_state =20)
rf.fit(X_train, y_train)

pred_ran=rf.predict(X_test)
accuracy_score(y_test,pred_ran)
# Out:
# 1.0

# %%
print("The accuracy score for Random Forest Algorithm is ",accuracy_score(y_test,pred_ran)*100,"%")
# Out:
# The accuracy score for Random Forest Algorithm is  100.0 %

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_scores = []
for k in range(1,24):
    knn_classifier = KNeighborsClassifier(n_neighbors = k)
    knn_classifier.fit(X_train, y_train)
    #knn_scores.append(knn_classifier.score(X_test, y_test))
    pred=knn_classifier.predict(X_test)
    
from sklearn.metrics import accuracy_score
print("The accuracy score of KNN classifier is : ",accuracy_score(y_test,pred)*100,"%")
# Out:
# The accuracy score of KNN classifier is :  81.25 %

# %%
from sklearn.metrics import classification_report,confusion_matrix
print (classification_report(y_test,pred))
print (confusion_matrix(y_test,pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       1.00      0.40      0.57         5
#           1       0.79      1.00      0.88        11
#
# avg / total       0.85      0.81      0.78        16
#
# [[ 2  3]
#  [ 0 11]]
